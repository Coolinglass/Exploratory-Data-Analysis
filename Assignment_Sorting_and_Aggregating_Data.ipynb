# %% [markdown]
# <a href="https://colab.research.google.com/github/Coolinglass/Applied-Machine-Learning-Projects/blob/master/Assignment_Sorting_and_Aggregating_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Sorting and Aggregating Data 📍 📍</h1></center>
#
# ---
#
# #### `READ THE DATASET`
#
# ---

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Analytics Vidhya/Sorting and Aggregating Data Python/dataset/time_series.csv')

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %% [markdown]
# #### `Convert the Datetime column to pandas datetime object`
#
# ---

# %%
# WRITE YOUR CODE HERE
data['Datetime'] = pd.to_datetime(data['Datetime'])
data.head()
# Out:
# <ipython-input-28-f1f490c50ba1>:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Datetime'] = pd.to_datetime(data['Datetime'])
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %% [markdown]
# ---
#
# ####  `Create the following features using the Datetime feature`
#
# - day of month
# - month
# - day of year
# - hour
#
# ---

# %%
# WRITE YOUR CODE HERE

# Day of Year
data['doy_ls_tran_pickup'] = data["Datetime"].dt.dayofyear

# Month of Year
data['moy_ls_tran_pickup'] = data["Datetime"].dt.month

# Day of Month
data['dow_ls_tran_pickup'] = data["Datetime"].dt.day

# Hour of Day
data['hrs_of_day_pickup'] = data["Datetime"].dt.hour

# %% [markdown]
# ---
#
# #### `Consider the following dataframe`
#
# ---

# %%
sample_df = pd.DataFrame({
    'id'   :  [1, 2, 3, 4, 5],
    'name' :  [ 'Akash', 'Akansha', 'Naman', 'Pulkit', 'Anand'],
    'marks':  [ 22, 23, 43, 41, 12]
})
sample_df
# Out:
#    id     name  marks
# 0   1    Akash     22
# 1   2  Akansha     23
# 2   3    Naman     43
# 3   4   Pulkit     41
# 4   5    Anand     12

# %% [markdown]
# #### Sort the  dataframe by `marks` column in descending order
#
# ---

# %%
# WRITE YOUR CODE HERE
sample_df.sort_values(by="marks",ascending=False)
# Out:
#    id     name  marks
# 2   3    Naman     43
# 3   4   Pulkit     41
# 1   2  Akansha     23
# 0   1    Akash     22
# 4   5    Anand     12

# %% [markdown]
# #### Consider another dataframe city
# ---

# %%
city = pd.DataFrame({
    'name' : ['Akash', 'Akansha', 'Pulkit', 'Anand', 'Naman'],
    'city' : ['Delhi', 'Gurugram', 'Gurugram', 'Delhi', 'Noida']
})
city
# Out:
#       name      city
# 0    Akash     Delhi
# 1  Akansha  Gurugram
# 2   Pulkit  Gurugram
# 3    Anand     Delhi
# 4    Naman     Noida

# %% [markdown]
# ***Use the dataframe `sample_df` and `city` and find out the marks of students who live in Gurugram.***
#
# ---

# %%
### Write your code here
gurugram_students = pd.merge(sample_df, city, on='name', how='inner')
gurugram_students[gurugram_students["city"] == "Gurugram"]
# Out:
#    id     name  marks      city
# 1   2  Akansha     23  Gurugram
# 3   4   Pulkit     41  Gurugram

# %% [markdown]
# #### `READ THE BIG MART SALES DATA`
#
# ---

# %%
data_BM = pd.read_csv('/content/drive/MyDrive/Analytics Vidhya/Data Visualzation - Big Mart Sales data/dataset/big_mart_sales.csv')

# %%
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### Find out the number of unique `Item_Type` in each of the `Outlet_Identifier`
#
# ---

# %%
# WRITE YOUR CODE HERE
data_BM.groupby('Outlet_Identifier')['Item_Type'].nunique()
# Out:
# Outlet_Identifier
# OUT010    16
# OUT013    16
# OUT017    16
# OUT018    16
# OUT019    16
# OUT027    16
# OUT035    16
# OUT045    16
# OUT046    16
# OUT049    16
# Name: Item_Type, dtype: int64

# %% [markdown]
# #### Find out the average `Item_Outlet_Sales` for each category of `Outlet_Size`
#
# ---

# %%
# WRITE YOUR CODE HERE
data_BM.groupby('Outlet_Size')['Item_Outlet_Sales'].mean()
# Out:
# Outlet_Size
# High      2298.995256
# Medium    2681.603542
# Small     1912.149161
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### Select only the categorical variables from the dataframe and use `get_dummies` function to convert those into the numerical ones.
#
# ---

# %%
# WRITE YOUR CODE HERE
data_BM.dtypes
dummies = pd.get_dummies(data_BM, columns=data_BM.select_dtypes(include='object').columns)

# %%
dummies
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  Item_Identifier_DRA12  Item_Identifier_DRA24  \
# ...
